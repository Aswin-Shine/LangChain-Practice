# %% [markdown]
# # **LLM CALL**

# %%
import os 
import load_dotenv
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

llm_openai = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

llm_openai.invoke("Hey GPT, Tell me a interesting fact about Formula 1").content
# Out:
# 'Sure! Here’s an interesting fact about Formula 1: \n\nThe fastest pit stop in Formula 1 history was performed by the Red Bull Racing team at the 2019 Brazilian Grand Prix. They changed all four tires on Max Verstappen’s car in just 1.82 seconds! This incredible speed is a result of precise teamwork, practice, and cutting-edge equipment, showcasing how crucial pit stops are in gaining a competitive edge during a race.'
