# %%
import os 
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
from langchain_core.runnables import RunnableLambda

load_dotenv()

llm_openai = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

str_parser = StrOutputParser()

# %%
# Task 1 - Prompt 
prompt_template = ChatPromptTemplate([
  ("system", "You are an automotive enthuaist"),
  ("user", "{input}")
])

# Task 2 - LLM 

# Task 3 - Str Parser

# Task 4 - Dictionary Maker
def dictionary_maker (text:str)-> dict :
  return {"text" : text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# Task 5 - Prompt
prompt_post = ChatPromptTemplate([
  ("system","You are a automotive social media post generator"),
  ("user", "Create a post for the following text for Linkedin/Instagram : {text}")
])

# Task 6 - LLM

# Task 7 - Str Parser

# %%
chain = prompt_template | llm_openai | str_parser | prompt_post | llm_openai | str_parser

chain.invoke("DeTomsao P900 Engine Details")
# Out:
# '🚀 Introducing the De Tomaso P900: A Masterpiece of Italian Engineering and Design 🇮🇹\n\nThe P900 is not just a hypercar; it’s a celebration of pure, naturally aspirated power and driver-focused performance. Here’s what makes its heart beat:\n\n🔥 **Engine:** Naturally aspirated 5.0L V12  \n⚡ **Power:** Around 900 horsepower (hence the name P900)  \n💪 **Torque:** 730 Nm (539 lb-ft) of raw, linear power  \n🔧 **Collaboration:** Developed with Roush Performance  \n🏎️ **Layout:** Mid-mounted for perfect balance and handling  \n🎵 **Sound:** A thrilling, unfiltered V12 roar that’s rare in today’s turbocharged world  \n\nThe P900 combines this beastly engine with a lightweight chassis and cutting-edge aerodynamics, delivering an exhilarating driving experience on both road and track.\n\nPure power. Pure passion. Pure De Tomaso.\n\nWant to dive deeper into the specs or performance figures? Drop a comment or DM!\n\n#DeTomasoP900 #Hypercar #V12Engine #ItalianDesign #PerformanceEngineering #Auto
# ...
